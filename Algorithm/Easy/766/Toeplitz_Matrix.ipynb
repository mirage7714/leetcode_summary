# %% [markdown]
# # 本題要判斷在array中，是否對角線的數值都相同
# 原題目連結: https://leetcode.com/problems/toeplitz-matrix/
#
# Given an m x n matrix, return true if the matrix is Toeplitz. Otherwise, return false.
#
# A matrix is Toeplitz if every diagonal from top-left to bottom-right has the same elements.
#
# 範例:
# Ex1:
# Input: matrix = [[1,2,3,4],[5,1,2,3],[9,5,1,2]]
# Output: true
# Explanation:
# In the above grid, the diagonals are:
# "[9]", "[5, 5]", "[1, 1, 1]", "[2, 2, 2]", "[3, 3]", "[4]".
# In each diagonal all elements are the same, so the answer is True.
#
# Ex2:
# Input: matrix = [[1,2],[2,2]]
# Output: false
# Explanation:
# The diagonal "[1, 2]" has different elements.

# %% [markdown]
# * 解題想法:
# ![image.png](attachment:image.png)
# 由於題目中要求檢查佐上至右下的對角線，仔細觀察後可以看出其實是對matrix的n與n+1進行比較並判斷是否相同
# 如果不相同則可直接中斷迴圈並回傳False，否則回傳True

# %%
class Solution:
    def isToeplitzMatrix(self, matrix: List[List[int]]) -> bool:
        is_diagonal = True
        if len(matrix) > 1:
            for n in range(len(matrix) - 1):
                if matrix[n][:-1] != matrix[n+1][1:]:
                    is_diagonal = False
                    break
        return is_diagonal
